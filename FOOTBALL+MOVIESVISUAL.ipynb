# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('football_players.csv', encoding='latin-1')

# Display basic info about the dataset
print(df.info())  # Column names, data types, and missing values
print(df.describe())  # Summary statistics of numerical columns
print(df.head())  # First few rows of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17981 non-null  object
#  1   Age                       17981 non-null  int64
#  2   Nationality               17981 non-null  object
#  3   Overall                   17981 non-null  float64
#  4   Acceleration              17981 non-null  float64
#  5   Aggression                17981 non-null  float64
#  6   Agility                   17981 non-null  float64
#  7   Balance                   17981 non-null  float64
#  8   Ball control              17981 non-null  float64
#  9   Composure                 17981 non-null  float64
#  10  Crossing                  17981 non-null  float64
#  11  Curve                     17981 non-null  float64
#  12  Dribbling                 17981 non-null  float64
# ...

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('football_players.csv', encoding='latin-1') # Added encoding for potential special characters

# Check if 'Position' or 'Preferred Positions' exists, else use a different relevant column
if 'Position' in df.columns:
    position_col = 'Position'
elif 'Preferred Positions' in df.columns:
    position_col = 'Preferred Positions'  # Using 'Preferred Positions' if 'Position' not found
else:
    # Handle case where neither column is found (e.g., print an error or choose another column)
    raise KeyError("Neither 'Position' nor 'Preferred Positions' column found in DataFrame.")


# Filter for players who are backs (defenders)
backs = df[df[position_col].str.contains('Back|Defender', case=False, na=False)]

# Check if there are any backs
if not backs.empty:
    # Find the back with the highest rating for 'Sliding tackle'
    highest_sliding_tackle_back = backs.loc[backs['Sliding tackle'].idxmax()]

    # Print the name of the back with the highest sliding tackle rating
    print(f"The back with the highest sliding tackle rating is: {highest_sliding_tackle_back['Name']}")
else:
    print("No backs found in the dataset.")
# Out:
# No backs found in the dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('max_column'.200)

# %%
# Visualize the distribution of key attributes like 'Overall', 'Potential', 'Age', etc.
sns.histplot(df['Overall'], bins=20)
plt.title('Distribution of Overall Player Ratings')
plt.show()

sns.boxplot(x='Preferred Positions', y='Overall', data=df)
plt.title('Overall Rating by Preferred Position')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
df.head(2)
# Out:
#                 Name  Age Nationality  Overall  Acceleration  Aggression  \
# 0  Cristiano Ronaldo   32    Portugal     94.0          89.0        63.0
# 1           L. Messi   30   Argentina     93.0          92.0        48.0
#
#    Agility  Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 0     89.0     63.0          93.0       95.0  ...        94.0            23.0
# 1     90.0     95.0          95.0       96.0  ...        85.0            26.0
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 0          91.0     92.0             31.0      80.0    85.0     88.0
# 1          87.0     73.0             28.0      59.0    90.0     85.0
#
#    Preferred Positions  Preferred Positions Type
# 0               ST LW                    Forward
# 1                  RW                    Forward
#
# [2 rows x 40 columns]

# %%
df.describe()
# Out:
#                 Age       Overall  Acceleration    Aggression       Agility  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  17981.000000
# mean      25.144541     66.247984     64.532618     55.789055     63.281464
# std        4.614272      6.987965     14.988620     17.485234     14.869227
# min       16.000000     46.000000     11.000000     11.000000     12.000000
# 25%       21.000000     62.000000     56.000000     43.000000     55.000000
# 50%       25.000000     66.000000     67.000000     59.000000     65.000000
# 75%       28.000000     71.000000     75.000000     69.000000     74.000000
# max       47.000000     94.000000     96.000000     96.000000     96.000000
#
#             Balance  Ball control     Composure     Crossing         Curve  \
# count  17981.000000  17981.000000  17981.000000  17981.00000  17981.000000
# mean      63.775596     58.004783     57.815472     49.71709     47.290028
# ...

# %%
df.isnull().sum()
# Out:
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Acceleration                0
# Aggression                  0
# Agility                     0
# Balance                     0
# Ball control                0
# Composure                   0
# Crossing                    0
# Curve                       0
# Dribbling                   0
# Finishing                   0
# Free kick accuracy          0
# GK diving                   0
# GK handling                 0
# GK kicking                  0
# GK positioning              0
# GK reflexes                 0
# Heading accuracy            0
# Interceptions               0
# Jumping                     0
# Long passing                0
# Long shots                  0
# Marking                     0
# Penalties                   0
# Positioning                 0
# Reactions                   0
# Short passing               0
# Shot power                  0
# ...

# %%
df.duplicated().sum()
# Out:
# 52

# %%
#display the duplicate rows.

# %%
#execute the code yourself to see the output

# %%
#print(duplicate_row)

# %%
#remove duplicates and keep the first occurance.

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      17981 non-null  object
#  1   Age                       17981 non-null  int64
#  2   Nationality               17981 non-null  object
#  3   Overall                   17981 non-null  float64
#  4   Acceleration              17981 non-null  float64
#  5   Aggression                17981 non-null  float64
#  6   Agility                   17981 non-null  float64
#  7   Balance                   17981 non-null  float64
#  8   Ball control              17981 non-null  float64
#  9   Composure                 17981 non-null  float64
#  10  Crossing                  17981 non-null  float64
#  11  Curve                     17981 non-null  float64
#  12  Dribbling                 17981 non-null  float64
# ...

# %%
df["Preferred Positions Type"].unique()
# Out:
# array(['Forward', 'GoalKeeper', 'Midfielder', 'Back'], dtype=object)

# %%
top_10_frowerd= df[df["Preferred Positions Type"]=="Forward"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the football players data

# Count the number of players from each country
player_counts = df['Nationality'].value_counts()

# Create the bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size if needed
sns.barplot(x=player_counts.index, y=player_counts.values)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Distribution of Players by Country')
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe
df = pd.read_csv('football_players.csv', encoding='latin-1')

# Filter for the desired countries
countries = ['Argentina', 'England', 'Brazil', 'Portugal']
filtered_df = df[df['Nationality'].isin(countries)]

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.barplot(x='Nationality', y='Overall', data=filtered_df)
plt.title('Overall Ratings of Players from Selected Countries')
plt.xlabel('Country')
plt.ylabel('Overall Rating')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataframe
df = pd.read_csv('football_players.csv', encoding='latin-1')

# Select top 20 players based on 'Overall'
top_20_players = df.sort_values(by=['Overall'], ascending=False).head(20)

# Create a cross-tabulation (contingency table)
position_counts = pd.crosstab(top_20_players['Preferred Positions Type'],
                               top_20_players['Nationality'])

# Create the heatmap
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.heatmap(position_counts, annot=True, cmap="YlGnBu", fmt="d")
plt.title('Distribution of Top 20 Players by Position and Nationality')
plt.xlabel('Nationality')
plt.ylabel('Preferred Positions Type')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()

# %%
top_10_frowerd
# Out:
#                     Name  Age          Nationality  Overall  Acceleration  \
# 0      Cristiano Ronaldo   32             Portugal     94.0          89.0
# 1               L. Messi   30            Argentina     93.0          92.0
# 2                 Neymar   25               Brazil     92.0          94.0
# 3              L. Suárez   30              Uruguay     92.0          88.0
# 5         R. Lewandowski   28               Poland     91.0          79.0
# ...                  ...  ...                  ...      ...           ...
# 17944             M. Foy   18              England     48.0          70.0
# 17948          R. Roache   17  Republic of Ireland     48.0          54.0
# 17959      N. McLaughlin   18             Scotland     47.0          69.0
# 17969         F. Prohart   18              Austria     47.0          62.0
# 17978           J. Young   17             Scotland     46.0          66.0
#
#        Aggression  Agility  Balance  Ball control  Composure  ...  Shot power  \
# ...

# %%
top_frowerd=df[df["Preferred Positions Type"]=="Forward"]

# %%
top_frowerd
# Out:
#                     Name  Age          Nationality  Overall  Acceleration  \
# 0      Cristiano Ronaldo   32             Portugal     94.0          89.0
# 1               L. Messi   30            Argentina     93.0          92.0
# 2                 Neymar   25               Brazil     92.0          94.0
# 3              L. Suárez   30              Uruguay     92.0          88.0
# 5         R. Lewandowski   28               Poland     91.0          79.0
# ...                  ...  ...                  ...      ...           ...
# 17944             M. Foy   18              England     48.0          70.0
# 17948          R. Roache   17  Republic of Ireland     48.0          54.0
# 17959      N. McLaughlin   18             Scotland     47.0          69.0
# 17969         F. Prohart   18              Austria     47.0          62.0
# 17978           J. Young   17             Scotland     46.0          66.0
#
#        Aggression  Agility  Balance  Ball control  Composure  ...  Shot power  \
# ...

# %%
top_Back= df[df["Preferred Positions Type"]=="Back"]

# %%
top_Back
# Out:
#                 Name  Age          Nationality  Overall  Acceleration  \
# 10      Sergio Ramos   31                Spain     90.0          75.0
# 17      G. Chiellini   32                Italy     89.0          68.0
# 24        L. Bonucci   30                Italy     88.0          62.0
# 25        J. Boateng   28              Germany     88.0          72.0
# 26          D. Godín   31              Uruguay     88.0          62.0
# ...              ...  ...                  ...      ...           ...
# 17968  T. Brownsword   17              England     47.0          55.0
# 17970     A. Kilgour   19              England     47.0          52.0
# 17972      A. Conway   19  Republic of Ireland     47.0          60.0
# 17974      J. Keeble   18              England     46.0          66.0
# 17980      L. Sackey   18                Ghana     46.0          48.0
#
#        Aggression  Agility  Balance  Ball control  Composure  ...  Shot power  \
# ...

# %%
top_Midfielder= df[df["Preferred Positions Type"]=="Midfielder"]

# %%
top_Midfielder
# Out:
#                Name  Age Nationality  Overall  Acceleration  Aggression  \
# 8          T. Kroos   27     Germany     90.0          60.0        60.0
# 11     K. De Bruyne   26     Belgium     89.0          76.0        68.0
# 13       A. Sánchez   28       Chile     89.0          88.0        80.0
# 14        L. Modri?   31     Croatia     89.0          75.0        62.0
# 19        P. Dybala   23   Argentina     88.0          88.0        48.0
# ...             ...  ...         ...      ...           ...         ...
# 17966   K. Fujikawa   18       Japan     47.0          59.0        55.0
# 17971      R. White   18     England     47.0          51.0        33.0
# 17973     T. Sawyer   18     England     46.0          65.0        43.0
# 17975  T. Käßemodel   28     Germany     46.0          25.0        52.0
# 17979  J. Lundstram   18     England     46.0          57.0        46.0
#
#        Agility  Balance  Ball control  Composure  ...  Shot power  \
# ...

# %%
top_GoalKeeper= df[df["Preferred Positions Type"]=="GoalKeeper"]
top_GoalKeeper
# Out:
#                 Name  Age          Nationality  Overall  Acceleration  \
# 4           M. Neuer   31              Germany     92.0          58.0
# 6             De Gea   26                Spain     90.0          57.0
# 12       T. Courtois   25              Belgium     89.0          46.0
# 18         G. Buffon   39                Italy     89.0          49.0
# 20          J. Oblak   24             Slovenia     88.0          43.0
# ...              ...  ...                  ...      ...           ...
# 17945      A. Dillon   20  Republic of Ireland     48.0          30.0
# 17949  M. McElhinney   19  Republic of Ireland     48.0          37.0
# 17951       M. Hurst   21             Scotland     48.0          40.0
# 17976      A. Kelsey   17              England     46.0          24.0
# 17977  B. Richardson   47              England     46.0          25.0
#
#        Aggression  Agility  Balance  Ball control  Composure  ...  Shot power  \
# ...

# %%
top_1_frowerd=top_frowerd.sort_values(by="Overall", ascending=False).head(3)

top_1_Midfielder=top_Midfielder.sort_values(by="Overall", ascending=False).head(3)

top_1_Back=top_Back.sort_values(by="Overall", ascending=False).head(4)

top_1_GoalKeeper=top_GoalKeeper.sort_values(by="Overall", ascending=False).head(1)

# %%
top_1_frowerd
#team(1)
# Out:
#                 Name  Age Nationality  Overall  Acceleration  Aggression  \
# 0  Cristiano Ronaldo   32    Portugal     94.0          89.0        63.0
# 1           L. Messi   30   Argentina     93.0          92.0        48.0
# 2             Neymar   25      Brazil     92.0          94.0        56.0
#
#    Agility  Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 0     89.0     63.0          93.0       95.0  ...        94.0            23.0
# 1     90.0     95.0          95.0       96.0  ...        85.0            26.0
# 2     96.0     82.0          95.0       92.0  ...        80.0            33.0
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 0          91.0     92.0             31.0      80.0    85.0     88.0
# 1          87.0     73.0             28.0      59.0    90.0     85.0
# 2          90.0     78.0             24.0      53.0    80.0     83.0
#
#    Preferred Positions  Preferred Positions Type
# ...

# %%
top_1_Midfielder
#team(1)
# Out:
#           Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 8     T. Kroos   27     Germany     90.0          60.0        60.0     71.0
# 13  A. Sánchez   28       Chile     89.0          88.0        80.0     90.0
# 14   L. Modri?   31     Croatia     89.0          75.0        62.0     93.0
#
#     Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 8      69.0          89.0       85.0  ...        87.0            69.0
# 13     87.0          87.0       86.0  ...        84.0            35.0
# 14     94.0          92.0       84.0  ...        73.0            73.0
#
#     Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 8           52.0     77.0             82.0      74.0    88.0     82.0
# 13          84.0     85.0             39.0      72.0    83.0     83.0
# 14          71.0     82.0             80.0      58.0    90.0     74.0
#
#     Preferred Positions  Preferred Positions Type
# ...

# %%
top_1_Back
#team(1)
# Out:
#             Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 10  Sergio Ramos   31       Spain     90.0          75.0        84.0     79.0
# 17  G. Chiellini   32       Italy     89.0          68.0        92.0     59.0
# 24    L. Bonucci   30       Italy     88.0          62.0        82.0     60.0
# 25    J. Boateng   28     Germany     88.0          72.0        82.0     58.0
#
#     Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 10     60.0          84.0       80.0  ...        79.0            91.0
# 17     64.0          57.0       82.0  ...        78.0            90.0
# 24     52.0          75.0       84.0  ...        74.0            88.0
# 25     53.0          71.0       86.0  ...        79.0            90.0
#
#     Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 10          77.0     84.0             89.0      81.0    63.0     66.0
# 17          78.0     68.0             92.0      91.0    50.0     45.0
# ...

# %%
top_1_GoalKeeper
#team(1)
# Out:
#        Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 4  M. Neuer   31     Germany     92.0          58.0        29.0     52.0
#
#    Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 4     35.0          48.0       70.0  ...        25.0            11.0
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 4          61.0     44.0             10.0      83.0    70.0     11.0
#
#    Preferred Positions  Preferred Positions Type
# 4                  GK                 GoalKeeper
#
# [1 rows x 40 columns]

# %%
top_10_penalties[0:5]#team(1)
# Out:
#                 Name  Age  Nationality  Overall  Acceleration  Aggression  \
# 255     M. Balotelli   26        Italy     82.0          77.0        70.0
# 136          Fabinho   23       Brazil     83.0          73.0        83.0
# 31    Z. Ibrahimovi?   35       Sweden     88.0          63.0        84.0
# 362       D. Perotti   28    Argentina     81.0          84.0        51.0
# 1047     P. Verhaegh   33  Netherlands     77.0          68.0        69.0
#
#       Agility  Balance  Ball control  Composure  ...  Shot power  \
# 255      70.0     50.0          85.0       79.0  ...        88.0
# 136      71.0     69.0          80.0       80.0  ...        75.0
# 31       81.0     41.0          88.0       91.0  ...        91.0
# 362      80.0     79.0          87.0       81.0  ...        73.0
# 1047     69.0     71.0          71.0       74.0  ...        66.0
#
#       Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  \
# ...

# %%
top_2_frowerd=top_frowerd.sort_values(by="Overall", ascending=False).head(6)

top_2_Midfielder=top_Midfielder.sort_values(by="Overall", ascending=False).head(6)

top_2_Back=top_Back.sort_values(by="Overall", ascending=False).head(8)

top_2_GoalKeeper=top_GoalKeeper.sort_values(by="Overall", ascending=False).head(3)

# %%
top_2_frowerd[3:6]
#team(2)
# Out:
#              Name  Age Nationality  Overall  Acceleration  Aggression  \
# 3       L. Suárez   30     Uruguay     92.0          88.0        78.0
# 5  R. Lewandowski   28      Poland     91.0          79.0        80.0
# 7       E. Hazard   26     Belgium     90.0          93.0        54.0
#
#    Agility  Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 3     86.0     60.0          91.0       83.0  ...        87.0            38.0
# 5     78.0     80.0          89.0       87.0  ...        88.0            19.0
# 7     93.0     91.0          92.0       87.0  ...        79.0            22.0
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 3          77.0     89.0             45.0      80.0    84.0     88.0
# 5          83.0     79.0             42.0      84.0    78.0     87.0
# 7          87.0     79.0             27.0      65.0    86.0     79.0
#
#    Preferred Positions  Preferred Positions Type
# ...

# %%
top_2_Midfielder[3:6]
#team(2)
# Out:
#             Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 11  K. De Bruyne   26     Belgium     89.0          76.0        68.0     80.0
# 19     P. Dybala   23   Argentina     88.0          88.0        48.0     91.0
# 22        Thiago   26       Spain     88.0          77.0        57.0     90.0
#
#     Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 11     75.0          87.0       84.0  ...        85.0            40.0
# 19     85.0          93.0       84.0  ...        82.0            20.0
# 22     86.0          92.0       83.0  ...        75.0            62.0
#
#     Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 11          75.0     87.0             51.0      73.0    90.0     82.0
# 19          84.0     83.0             20.0      65.0    84.0     88.0
# 22          68.0     75.0             64.0      59.0    86.0     90.0
#
#     Preferred Positions  Preferred Positions Type
# ...

# %%
top_2_Back[4:8]
#team(2)
# Out:
#             Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 26      D. Godín   31     Uruguay     88.0          62.0        86.0     63.0
# 27    M. Hummels   28     Germany     88.0          62.0        66.0     64.0
# 30  Thiago Silva   32      Brazil     88.0          70.0        77.0     74.0
# 39       Marcelo   29      Brazil     87.0          77.0        84.0     77.0
#
#     Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 26     58.0          76.0       82.0  ...        67.0            89.0
# 27     58.0          77.0       91.0  ...        71.0            90.0
# 30     68.0          80.0       83.0  ...        74.0            88.0
# 39     82.0          88.0       85.0  ...        83.0            87.0
#
#     Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 26          67.0     67.0             86.0      80.0    52.0     47.0
# 27          65.0     66.0             92.0      85.0    79.0     60.0
# ...

# %%
top_GoalKeeper[1:2]
#team(2)
# Out:
#      Name  Age Nationality  Overall  Acceleration  Aggression  Agility  \
# 6  De Gea   26       Spain     90.0          57.0        38.0     60.0
#
#    Balance  Ball control  Composure  ...  Shot power  Sliding tackle  \
# 6     43.0          42.0       64.0  ...        31.0            13.0
#
#    Sprint speed  Stamina  Standing tackle  Strength  Vision  Volleys  \
# 6          58.0     40.0             21.0      64.0    68.0     13.0
#
#    Preferred Positions  Preferred Positions Type
# 6                  GK                 GoalKeeper
#
# [1 rows x 40 columns]

# %%
top_10_penalties[5:10]
#team(2)
# Out:
#               Name  Age  Nationality  Overall  Acceleration  Aggression  \
# 3148     T. Simons   40      Belgium     73.0          32.0        72.0
# 286      L. Baines   32      England     82.0          73.0        74.0
# 262       M. Kruse   29      Germany     82.0          74.0        63.0
# 196       Y. Touré   34  Ivory Coast     83.0          61.0        78.0
# 1304  Diego Castro   34        Spain     76.0          69.0        65.0
#
#       Agility  Balance  Ball control  Composure  ...  Shot power  \
# 3148     31.0     59.0          68.0       75.0  ...        71.0
# 286      74.0     84.0          80.0       81.0  ...        84.0
# 262      75.0     76.0          86.0       86.0  ...        81.0
# 196      58.0     56.0          82.0       83.0  ...        86.0
# 1304     72.0     82.0          80.0       81.0  ...        73.0
#
#       Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  \
# ...

# %%
top_10_penalties = df.sort_values(by=['Penalties'], ascending=False).head(10)
top_10_penalties
# Out:
#                 Name  Age  Nationality  Overall  Acceleration  Aggression  \
# 255     M. Balotelli   26        Italy     82.0          77.0        70.0
# 136          Fabinho   23       Brazil     83.0          73.0        83.0
# 31    Z. Ibrahimovi?   35       Sweden     88.0          63.0        84.0
# 362       D. Perotti   28    Argentina     81.0          84.0        51.0
# 1047     P. Verhaegh   33  Netherlands     77.0          68.0        69.0
# 3148       T. Simons   40      Belgium     73.0          32.0        72.0
# 286        L. Baines   32      England     82.0          73.0        74.0
# 262         M. Kruse   29      Germany     82.0          74.0        63.0
# 196         Y. Touré   34  Ivory Coast     83.0          61.0        78.0
# 1304    Diego Castro   34        Spain     76.0          69.0        65.0
#
#       Agility  Balance  Ball control  Composure  ...  Shot power  \
# 255      70.0     50.0          85.0       79.0  ...        88.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataframe
df = pd.read_csv('football_players.csv', encoding='latin-1')

# Select the top 10 players based on 'Overall'
top_10_players = df.sort_values(by=['Overall'], ascending=False).head(10)

# Create a bar plot to show the distribution of players by country
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
sns.countplot(x='Nationality', data=top_10_players, order=top_10_players['Nationality'].value_counts().index)
plt.title('Distribution of Top 10 Players by Country')
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. Load and filter the DataFrame:
df = pd.read_csv('football_players.csv', encoding='latin-1')
messi_ronaldo_df = df[df['Name'].isin(['L. Messi', 'Cristiano Ronaldo'])]

# 2. Select desired attributes:
attributes = ['Heading accuracy', 'Interceptions', 'Long passing', 'Long shots',
              'Marking', 'Penalties', 'Positioning', 'Reactions', 'Short passing',
              'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
              'Strength', 'Vision', 'Volleys', 'Acceleration',
              'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
              'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy']

# 3. Prepare data for plotting:
player_names = messi_ronaldo_df['Name'].tolist()
attribute_values = messi_ronaldo_df[attributes].values.T  # Transpose for plotting

# 4. Create the bar plot:
x = np.arange(len(attributes))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))  # Adjust figure size as needed
rects1 = ax.bar(x - width/2, attribute_values[:, 0], width, label=player_names[0])
rects2 = ax.bar(x + width/2, attribute_values[:, 1], width, label=player_names[1])

# 5. Customize the plot:
ax.set_ylabel('Attribute Value')
ax.set_title('Comparison of Messi and Ronaldo Attributes')
ax.set_xticks(x)
ax.set_xticklabels(attributes, rotation=45, ha='right')  # Rotate labels for readability
ax.legend()
fig.tight_layout()
plt.show()
